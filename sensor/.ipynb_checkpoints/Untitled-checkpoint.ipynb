# %%
'''
参考
https://qiita.com/mhangyo/items/76db7c6a6ebba6cf4330

dtypeに関する資料
http://discexuno.wp.xdomain.jp/machine-learning/python_fromfile_fromstring/

3Dfigure
https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-5-3d/
'''
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import cv2 
from scipy.fftpack import fft,ifft
import os
import glob
from pylab import *
import math

# %%
#f = open(r"\\FS1\Maedalab\home\junjie-hua\wave\fourD_sensor\rawdata\20191101\test1_belly\Height\Height Row 0000.data",mode='rb')#0列目
#topo = np.fromfile(f, dtype='float64',sep='').reshape(256,20000)

# %%
#print(topo)

# %%
path = "//FS1//Maedalab//home//junjie-hua//wave//fourD_sensor//rawdata//20191101//test1_belly//Height" #faulder
files= os.listdir(path) #all files in the faulder
s = []
n = 0

os.chdir("//FS1//Maedalab//home//junjie-hua//wave//fourD_sensor//rawdata//20191101//test1_belly//Height")
for file in glob.glob("*.data"): 
    #print(file)
    
    f = open(path + "//" + file ,mode='rb')#n列目
    name='topo'+str(n)  
    locals()['topo'+str(n)]= np.fromfile(f, dtype='float64',sep='').reshape(256,20000)
    print(file,"has ended")
    n = n + 1 
     
print(n)
# Out:
# Height Row 0000.data has ended
# Height Row 0002.data has ended
# Height Row 0004.data has ended
# Height Row 0006.data has ended
# Height Row 0008.data has ended
# Height Row 0010.data has ended
# Height Row 0012.data has ended
# Height Row 0014.data has ended
# Height Row 0016.data has ended
# Height Row 0018.data has ended
# Height Row 0020.data has ended
# Height Row 0022.data has ended
# Height Row 0024.data has ended
# Height Row 0026.data has ended
# Height Row 0028.data has ended
# Height Row 0030.data has ended
# Height Row 0032.data has ended
# Height Row 0034.data has ended
# Height Row 0036.data has ended
# Height Row 0038.data has ended
# Height Row 0040.data has ended
# Height Row 0042.data has ended
# Height Row 0044.data has ended
# Height Row 0046.data has ended
# Height Row 0048.data has ended
# Height Row 0050.data has ended
# Height Row 0052.data has ended
# Height Row 0054.data has ended
# Height Row 0056.data has ended
# Height Row 0058.data has ended
# Height Row 0060.data has ended
# Height Row 0062.data has ended
# Height Row 0064.data has ended
# Height Row 0066.data has ended
# Height Row 0068.data has ended
# Height Row 0070.data has ended
# Height Row 0072.data has ended
# Height Row 0074.data has ended
# Height Row 0076.data has ended
# Height Row 0078.data has ended
# Height Row 0080.data has ended
# Height Row 0082.data has ended
# Height Row 0084.data has ended
# Height Row 0086.data has ended
# Height Row 0088.data has ended
# Height Row 0090.data has ended
# Height Row 0092.data has ended
# Height Row 0094.data has ended
# Height Row 0096.data has ended
# Height Row 0098.data has ended
# Height Row 0100.data has ended
# Height Row 0102.data has ended
# Height Row 0104.data has ended
# Height Row 0106.data has ended
# Height Row 0108.data has ended
# Height Row 0110.data has ended
# Height Row 0112.data has ended
# Height Row 0114.data has ended
# Height Row 0116.data has ended
# Height Row 0118.data has ended
# Height Row 0120.data has ended
# Height Row 0122.data has ended
# Height Row 0124.data has ended
# Height Row 0126.data has ended
# Height Row 0128.data has ended
# Height Row 0130.data has ended
# Height Row 0132.data has ended
# Height Row 0134.data has ended
# Height Row 0136.data has ended
# Height Row 0138.data has ended
# Height Row 0140.data has ended
# Height Row 0142.data has ended
# Height Row 0144.data has ended
# Height Row 0146.data has ended
# Height Row 0148.data has ended
# Height Row 0150.data has ended
# Height Row 0152.data has ended
# Height Row 0154.data has ended
# Height Row 0156.data has ended
# Height Row 0158.data has ended
# Height Row 0402.data has ended
# Height Row 0404.data has ended
# Height Row 0406.data has ended
# Height Row 0408.data has ended
# Height Row 0410.data has ended
# Height Row 0412.data has ended
# Height Row 0414.data has ended
# Height Row 0416.data has ended
# Height Row 0418.data has ended
# Height Row 0420.data has ended
# Height Row 0422.data has ended
# Height Row 0424.data has ended
# Height Row 0426.data has ended
# Height Row 0428.data has ended
# Height Row 0430.data has ended
# Height Row 0432.data has ended
# Height Row 0434.data has ended
# Height Row 0436.data has ended
# Height Row 0438.data has ended
# Height Row 0440.data has ended
# Height Row 0442.data has ended
# Height Row 0444.data has ended
# Height Row 0446.data has ended
# Height Row 0448.data has ended
# Height Row 0450.data has ended
# Height Row 0452.data has ended
# Height Row 0454.data has ended
# Height Row 0456.data has ended
# Height Row 0458.data has ended
# Height Row 0460.data has ended
# Height Row 0462.data has ended
# Height Row 0464.data has ended
# Height Row 0466.data has ended
# Height Row 0468.data has ended
# Height Row 0470.data has ended
# Height Row 0472.data has ended
# Height Row 0474.data has ended
# Height Row 0476.data has ended
# Height Row 0478.data has ended
# Height Row 0480.data has ended
# Height Row 0482.data has ended
# Height Row 0484.data has ended
# Height Row 0486.data has ended
# Height Row 0488.data has ended
# Height Row 0490.data has ended
# Height Row 0492.data has ended
# Height Row 0494.data has ended
# Height Row 0496.data has ended
# Height Row 0498.data has ended
# Height Row 0500.data has ended
# Height Row 0502.data has ended
# 252

# %%
#names = locals()
#k = names['topo' + str(251) ][255,5000]
#print(type(k))



names = locals()
def f(x,y): 
    k = names['topo'+str(y)][x,1]
    #k = topo251[255,5000]
    return k

#print(f(255,251))

# X, Y value
x = np.linspace(0,256-1,256)
y = np.linspace(0,252-1,252)
X,Y = np.meshgrid(x,y)
#print(X.shape)
#print(Y.shape)


Z = [[0 for i in range(X.shape[1])] for i in range(Y.shape[0])]

for i in range(X.shape[0]):
    #print(i)
    for j in range(X.shape[1]):
        #print(j)
        Z[i][j] = f(j,i)

Z_array=np.array(Z)# turn list into array
#Z_array=np.log10(Z_array)
Z_array = Z_array/1e50
print(Z_array)



"""
# 3Dグラフを作成する
fig = plt.figure()
ax = Axes3D(fig)

ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")


surface= ax.plot_surface(X, Y, Z_array, rstride=1, cstride=1, cmap=plt.get_cmap('rainbow'))
fig.colorbar(surface)


plt.show()
"""



cp = plt.contourf(X, Y, Z_array)
plt.colorbar(cp)

ax.set_title('Contour Plot')
ax.set_xlabel('x ')
ax.set_ylabel('y ')
plt.show()
# Out:
# E:\anaconda\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# [[ 5.79941800e-173 -6.08191306e-256 -1.67568523e-152 ... -3.15874288e-286
#   -1.89195125e-148 -1.11720989e+193]
#  [ 3.06582945e-181  2.95711579e-211 -2.17568355e-070 ... -1.38032713e-158
#   -0.00000000e+000 -2.14426673e+248]
#  [ 4.59307139e-006 -3.54166400e+204 -7.50391181e-229 ... -5.53392653e-148
#   -3.87344563e-151  6.32247826e-028]
#  ...
#  [ 7.86178788e-184 -1.77724810e-301  4.52813760e-285 ... -9.18420212e-278
#    8.75072948e-144 -2.57804935e-156]
#  [ 1.16849356e-240  2.58073755e+165  0.00000000e+000 ...  2.26247952e+019
#   -1.24801552e+177 -6.86474591e-118]
#  [ 1.44506915e-297  4.43832840e-021  1.19604899e+171 ...  8.04023663e+112
#   -1.30765518e+232  0.00000000e+000]]
