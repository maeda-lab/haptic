# %%
"""
https://blog.csdn.net/Bugest/article/details/81119980
https://blog.csdn.net/u011440558/article/details/78272629   --ファイル名順
"""


# -*- coding: UTF-8 -*-
import os
import cv2
import time
 

def picvideo(path,size):
    filelist = os.listdir(path) 
    filelist.sort(key= lambda x:int(x[:-4]))
    #print(filelist)
    fps = 10
    file_path = "C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//color_map//video//test1_belly" + "video_global" + ".mp4"#export
    fourcc = cv2.VideoWriter_fourcc('D', 'I', 'V', 'X')#encode
    video = cv2.VideoWriter( file_path, fourcc, fps, size )
 
    for item in filelist:
        if item.endswith('.png'):   
            #print(item)
            item = path + '/' + item 
            img = cv2.imread(item)  
            video.write(img)        
    video.release() 
    
    



path = "C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//color_map//test1_belly//global//"    
size =(432,288)
picvideo(path,size)#// is necessary
print("end")
# Out:
# 0.png
# 100.png
# 200.png
# 300.png
# 400.png
# 500.png
# 600.png
# 700.png
# 800.png
# 900.png
# 1000.png
# 1100.png
# 1200.png
# 1300.png
# 1400.png
# 1500.png
# 1600.png
# 1700.png
# 1800.png
# 1900.png
# 2000.png
# 2100.png
# 2200.png
# 2300.png
# 2400.png
# 2500.png
# 2600.png
# 2700.png
# 2800.png
# 2900.png
# 3000.png
# 3100.png
# 3200.png
# 3300.png
# 3400.png
# 3500.png
# 3600.png
# 3700.png
# 3800.png
# 3900.png
# 4000.png
# 4100.png
# 4200.png
# 4300.png
# 4400.png
# 4500.png
# 4600.png
# 4700.png
# 4800.png
# 4900.png
# 5000.png
# 5100.png
# 5200.png
# 5300.png
# 5400.png
# 5500.png
# 5600.png
# 5700.png
# 5800.png
# 5900.png
# 6000.png
# 6100.png
# 6200.png
# 6300.png
# 6400.png
# 6500.png
# 6600.png
# 6700.png
# 6800.png
# 6900.png
# 7000.png
# 7100.png
# 7200.png
# 7300.png
# 7400.png
# 7500.png
# 7600.png
# 7700.png
# 7800.png
# 7900.png
# 8000.png
# 8100.png
# 8200.png
# 8300.png
# 8400.png
# 8500.png
# 8600.png
# 8700.png
# 8800.png
# 8900.png
# 9000.png
# 9100.png
# ...
