# %% [markdown]
# # 参考
# https://qiita.com/mhangyo/items/76db7c6a6ebba6cf4330
#
# dtypeに関する資料
# http://discexuno.wp.xdomain.jp/machine-learning/python_fromfile_fromstring/
# https://docs.python.org/3/library/struct.html
#
# 3Dfigure
# https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-5-3d/
#
# 時空間フィルタリング
# https://home.hiroshima-u.ac.jp/kikuuwe/pub/05_acmtap.pdf
# http://www.eeengblog.com/engineer/%E3%83%95%E3%83%BC%E3%83%AA%E3%82%A8%E5%A4%89%E6%8F%9B%E3%82%92%E4%BD%BF%E3%81%A3%E3%81%9F%E7%94%BB%E5%83%8F%E8%A7%A3%E6%9E%90
#
#
#
# # 付録ーーデータの展開法
#
# 一つの実験についてのデータは四つのフォルダーに分けております。
# そのうち、「Height」と書いてるフォルダーに変異データが入ってます。
# そのフォルダーの中には縦方向（Y軸）の画素分のデータファイルがあります。
# 一つのファイルには一行についての画像枚分のデータが横方向（X軸）の画素分重ねております。
#
# つまり、X行、Y棚、Fフレームのデータポイントを見つけるには
# Y個目のファイルを開いて、X×フレーム数（16666frames=500fps×33.3s）＋F　のインデックスでXYFのデータがあります。
#
# データ自体は64bit doubleです。バイトオーダーはビッグエンディアンです (byte order: big endian)。ヘッダーはないです。
#
#
# 他の設定に関する情報元(resolution/framerate/downsampling,etc)　　\\FS1\Maedalab\home\junjie-hua\wave\fourD_sensor\rawdata\20191101\Captures
#
#
# f = open(r"\\FS1\Maedalab\home\junjie-hua\wave\fourD_sensor\rawdata\20191101\test1_belly\Height\Height Row 0000.data",mode='rb')#0列目
# topo = np.fromfile(f, dtype='float64',sep='').reshape(256,20000) #float64の形で読み込むと，5120000の数列ができました．bellyの計測時間=20*1000msため，256*20000とreshapeしました．x軸上のサンプリング点が256個となります．
#
#
# # 04/21 update
# ### 呼吸のみのデータに対して、HPF・LPFをかけて、
# →HPFをかけたデータに対象としたい高周波成分にエネルギーが出てこないかを確認(パワースペクトル)
#
# ### 	エネルギーがなければ
# 		HPFをなぞったデータにかけて、スペクトルの計算し、エネルギーがあることを確認
# 		エネルギーがあるならば、コヒーレンスを計算する
# 			※先程の論文では、他の周波数成分を殺していないかを確認
#
# ### 	エネルギーがあれば
# 		LPFに出てきたスペクトルによるAM変調・FM変調として、HPFをかけたデータに現れていないかを確認、出ていればそれを除去する　それで消えていればコヒーレンスを計算する
#
# ### 時空間に連続なHPFはないのか？
# 	これをしらべて、データにかける
# →スペクトルの確認、コヒーレンス計算

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import cv2 
from scipy.fftpack import fft,ifft
import scipy.fftpack as sfft
from scipy.interpolate import interp1d
import os
import glob
from pylab import *
import math
import matplotlib.animation as animation
from ipywidgets import IntProgress
from IPython.display import display
from scipy import signal
from matplotlib import mlab

# %%
path = "//FS1//Maedalab//home//junjie-hua//wave//fourD_sensor//rawdata//20191101//test1_belly//Height" #belly上の計測データ元　
#path = "C://Users//huaju//Documents//data//fourD_sensor//20191101//test1_belly//Height" #belly上の計測データ元　

files = os.listdir(path) #all files in the faulder　縦方向(y軸)のデータファイル
s = []
ynum = 0

print("reading files")
os.chdir("//FS1//Maedalab//home//junjie-hua//wave//fourD_sensor//rawdata//20191101//test1_belly//Height") #local()関数を利用するためのコードです
#os.chdir("C://Users//huaju//Documents//data//fourD_sensor//20191101//test1_belly//Height") #local()関数を利用するためのコードです
for file in glob.glob("*.data"): 
    f = open(path + "//" + file ,mode='rb')#n列目　rb= read binary
    name = 'topo'+str(ynum)  #一つのファイルには一行についての画像枚分のデータが横方向（X軸）の画素分のデータを変数topo+str(n)に入れます
    locals()['topo'+str(ynum)]= np.fromfile(f, dtype='>d').reshape(256,20000) 
    # https://docs.python.org/3/library/struct.html
    # ">" means big endian, "d" means double. 5120000の数列ができました．bellyの計測時間=20*1000msため，256*20000とreshapeしました．x軸上のサンプリング点が256個となります．
    #print(file,"has ended")
    ynum = ynum + 1 

print("end reading")
print(ynum ,"y-axis files") #y軸上サンプリング点の数を数えます--252個
xnum = 256
T = 20000
# Out:
# reading files
# end reading
# 252 y-axis files

# %%
# (x,y,t)のデータを取り出すための関数 
names = locals()
def f(x,y,t): 
    k = names['topo'+str(y)][x,t]  #topo_str(y)の数列から，(x,t)のデータを取り出します
    return k
#print(f(255,251,19999))
print(f(0,0,0))


# X, Y value
x = np.linspace(0,xnum-1,xnum)
y = np.linspace(0,ynum-1,ynum)
X,Y = np.meshgrid(x,y)  #サンプリング点の数：x軸256個， y軸252個
#Z = [[0 for i in range(X.shape[1])] for i in range(Y.shape[0])] #Z--y行x列
Z = [[0 for row in range(xnum)] for col in range(ynum)]  #Z--x列y行    e.g. arr2D = [[ 0 for col in range(10) ] for row in range(4) ]-- 10列4行
# Out:
# 0.743598271334937

# %% [markdown]
# ## color map animation

# %%
"""
print(" color map start")
for t in range(T):
    if t % 100 == 0:
        for y in range(ynum): #y axis
            for x in range(xnum): # x axis
                Z[y][x] = f(x,y,t)    
        Z_array = np.array(Z)# turn list into array
        
        #color mapを作成する
        #plt.pcolormesh(X, Y, Z_array, cmap='hsv') # 等高線図の生成。cmapで色付けの規則を指定する。
        plt.pcolormesh(X, Y, Z_array, cmap='jet') # 等高線図の生成。cmapで色付けの規則を指定する。


        pp=plt.colorbar (orientation="vertical") # カラーバーの表示 

        plt.xlabel('X', fontsize=18)
        plt.ylabel('Y', fontsize=18)
        plt.title("T = %s ms"% (t))

        #print(t)
        #plt.savefig("//FS1//Maedalab//home//junjie-hua//wave//fourD_sensor//rawdata//20191101//Captures//animation//color_map//test1_belly//total//" + str(t) + ".png")
        plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//color_map//test1_belly//global//" + str(t) + ".png")
        #plt.show()
        plt. close()
    else:
        continue
        
print("color map end")
"""
# Out:
# '\nprint(" color map start")\nfor t in range(T):\n    if t % 100 == 0:\n        for y in range(ynum): #y axis\n            for x in range(xnum): # x axis\n                Z[y][x] = f(x,y,t)    \n        Z_array = np.array(Z)# turn list into array\n        \n        #color mapを作成する\n        #plt.pcolormesh(X, Y, Z_array, cmap=\'hsv\') # 等高線図の生成。cmapで色付けの規則を指定する。\n        plt.pcolormesh(X, Y, Z_array, cmap=\'jet\') # 等高線図の生成。cmapで色付けの規則を指定する。\n\n\n        pp=plt.colorbar (orientation="vertical") # カラーバーの表示 \n\n        plt.xlabel(\'X\', fontsize=18)\n        plt.ylabel(\'Y\', fontsize=18)\n        plt.title("T = %s ms"% (t))\n\n        #print(t)\n        #plt.savefig("//FS1//Maedalab//home//junjie-hua//wave//fourD_sensor//rawdata//20191101//Captures//animation//color_map//test1_belly//total//" + str(t) + ".png")\n        plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//color_map//test1_belly//global//" + str(t) + ".png")\n        #plt.show()\n
# ...

# %%
"""
0-5600ms  pure breath

16400-19999ms pure breath

12/18 sensor side+display side　一直線上(left right二本　振動子につくとついていない方)のfftを見たい 
まず直線上で決着付ける　振動が見えるなら，画像全体fftを見る


"""

"""
xmin = 0
xmax = 255
ymin =0
ymax =251
tmin = 5000
tmax = 10000

# Initialize a progess bar
progress = IntProgress()
progress.max = tmax - tmin
progress.description = '(Init)'
display(progress)




for t in range(tmin,tmax):
    for y in range(ymin,ymax):#y軸
        for x in range(xmin,xmax):#x軸
            Z[y-ymin][x-xmin] = f(x,y,t) - f(x,y,0)
    Z_array = np.array(Z)# turn list into array
    h,w=Z_array.shape  #h、wにGのサイズを代入
    fftsize=max(h,w)  #フーリエ変換を行う際の行列のサイズを決定
    z_fourier=sfft.fftshift(sfft.fft2(Z_array,(fftsize,fftsize)))#Gを高速フーリエ変換
    plt.plot(np.log(np.abs(z_fourier)))
    plt.title("T = %s ms"% (t))
             
    #plt.savefig("//FS1//Maedalab//home//junjie-hua//wave//fourD_sensor//rawdata//20191101//Captures//animation//color_map//test3_sensor//narrow//" + str(t) + ".png")
    plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//color_map//test1_belly//breath//" + str(t) + ".png")
    #plt.show()
    plt. close()
    progress.value += 1
    progress.description = '%s'%(t)



progress.description = '(Done)'





"""
# Out:
# '\nxmin = 0\nxmax = 255\nymin =0\nymax =251\ntmin = 5000\ntmax = 10000\n\n# Initialize a progess bar\nprogress = IntProgress()\nprogress.max = tmax - tmin\nprogress.description = \'(Init)\'\ndisplay(progress)\n\n\n\n\nfor t in range(tmin,tmax):\n    for y in range(ymin,ymax):#y軸\n        for x in range(xmin,xmax):#x軸\n            Z[y-ymin][x-xmin] = f(x,y,t) - f(x,y,0)\n    Z_array = np.array(Z)# turn list into array\n    h,w=Z_array.shape  #h、wにGのサイズを代入\n    fftsize=max(h,w)  #フーリエ変換を行う際の行列のサイズを決定\n    z_fourier=sfft.fftshift(sfft.fft2(Z_array,(fftsize,fftsize)))#Gを高速フーリエ変換\n    plt.plot(np.log(np.abs(z_fourier)))\n    plt.title("T = %s ms"% (t))\n             \n    #plt.savefig("//FS1//Maedalab//home//junjie-hua//wave//fourD_sensor//rawdata//20191101//Captures//animation//color_map//test3_sensor//narrow//" + str(t) + ".png")\n    plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//color_map//test1_belly//breath//" + str(t) + ".png")\n    #pl
# ...

# %% [markdown]
# # 時空間フィルタリング
#
# https://www.jstage.jst.go.jp/article/isciesci/62/2/62_76/_pdf
#
# https://www.jstage.jst.go.jp/article/fss/25/0/25_0_19/_pdf
#
# https://www.jstage.jst.go.jp/article/japannctam/59/0/59_0_181/_pdf
#
# http://mbe.eng.niigata-u.ac.jp/MEHI/Announce/211/OS11-5.pdf
# 19 チャンネルとし，通過帯域 8～13Hz
# でフィルタリング後，処理区間 0.5 秒で包絡処理
#
#
# PSDの求め方
# https://scipy-lectures.org/intro/scipy/auto_examples/plot_spectrogram.html
#
# コヒーレンス求め方
# https://org-technology.com/posts/matplotlib-coherence.html
#
# クロスペクトル
# https://org-technology.com/posts/matplotlib-psd-csd.html
#
# ## 備考
# 呼吸周波数約0.25Hz
#
# なぞり約0.5Hz
#
# 呼吸のみ　0-5600ms
#
# 0-4095msの間での4096個データを使う
#
# 呼吸+なぞり　6500-16000ms
#
# 7000-11095msの間での4096個データを使う
#
# x~(0,255)
#
# y~(0,251)
#
# 256*252 チャネルに対し

# %%
# 点の設置
xmin = 130
ymin = 140
tmin_breath = 2048     #t=300msあたりのノイズを避けたいので
tmax_breath = 4095
#tmin_tracing = 6900
#tmax_tracing = 10995
tmin_tracing = 7000
tmax_tracing = 15191
N = tmax_breath-tmin_breath+1
N_tracing = tmax_tracing-tmin_tracing+1

#  FFTのための設定
Fs = 1000;                 # sampling rate
Ts = 1.0/Fs;                # sampling interval 
t_breath = np.arange(tmin_breath/Fs,(tmax_breath+1)/Fs,Ts)       # time vector of breath only
t_tracing = np.arange(tmin_tracing/Fs,(tmax_tracing+1)/Fs,Ts)       # time vector of tracing




z_breath = zeros(tmax_breath - tmin_breath + 1)
z_tracing = zeros(tmax_tracing - tmin_tracing + 1)
for timing in range(tmin_breath,tmax_breath):  #breath only時系列を取得
    z_breath[timing - tmin_breath]= f(xmin,ymin,timing)

for timing in range(tmin_tracing,tmax_tracing):  #tracing時系列を取得
    z_tracing[timing - tmin_tracing]= f(xmin,ymin,timing)

    

'''
breath only
'''
Z_breath = np.array(z_breath)# turn list into array
# 高速フーリエ変換(FFT)
F = np.fft.fft(Z_breath) 




# FFTの複素数結果を絶対に変換
F_abs = np.abs(F)
# 振幅をもとの信号に揃える
F_abs_amp = F_abs / N * 2 # 交流成分はデータ数で割って2倍
F_abs_amp[0] = F_abs_amp[0] / 2 # 直流成分（今回は扱わないけど）は2倍不要

# 周波数軸のデータ作成
fq_breath = np.linspace(0, Fs, N) # 周波数軸　linspace(開始,終了,分割数)

# グラフ表示
fig = plt.figure(figsize=(12, 4))
# 信号のグラフ（時間軸）
ax2 = fig.add_subplot(121)
plt.xlabel('time(sec)', fontsize=14)
plt.ylabel('amplitude', fontsize=14)
plt.plot(t_breath, Z_breath)
fig.suptitle('Breath only', fontsize=16)


# FFTのグラフ（周波数軸）
ax2 = fig.add_subplot(122)
plt.xlabel('freqency(Hz)', fontsize=14)
plt.ylabel('amplitude', fontsize=14)
plt.plot(fq_breath[:int(N/2)+1], F_abs_amp[:int(N/2)+1]) # ナイキスト定数まで表示
ax2.set_xlim([30,250])
ax2.set_ylim([0,0.01])


#plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//filter//test1_belly//breath_only_zoom.png")


'''
tracing
'''
Z_tracing = np.array(z_tracing)# turn list into array

# 高速フーリエ変換(FFT)
F_tracing = np.fft.fft(Z_tracing) 

# FFTの複素数結果を絶対に変換
F_abs = np.abs(F_tracing)
# 振幅をもとの信号に揃える
F_abs_amp = F_abs / N_tracing * 2 # 交流成分はデータ数で割って2倍
F_abs_amp[0] = F_abs_amp[0] / 2 # 直流成分（今回は扱わないけど）は2倍不要

# 周波数軸のデータ作成
fq_tracing = np.linspace(0, Fs, N_tracing) # 周波数軸　linspace(開始,終了,分割数)


# グラフ表示
fig = plt.figure(figsize=(12, 4))
# 信号のグラフ（時間軸）
ax2 = fig.add_subplot(121)
plt.xlabel('time(sec)', fontsize=14)
plt.ylabel('amplitude', fontsize=14)
plt.plot(t_tracing, Z_tracing)
fig.suptitle('Tracing', fontsize=16)


# FFTのグラフ（周波数軸）
ax2 = fig.add_subplot(122)
plt.xlabel('freqency(Hz)', fontsize=14)
plt.ylabel('amplitude', fontsize=14)
plt.plot(fq_tracing[:int(N_tracing/2)+1], F_abs_amp[:int(N_tracing/2)+1]) # ナイキスト定数まで表示
ax2.set_xlim([30,250])
ax2.set_ylim([0,0.1])


#plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//filter//test1_belly//tracing_zoom.png")
# Out:
# (0, 0.1)

# %% [markdown]
# # filtering

# %%
'''
tracing
'''
#まずはなぞりの時系列データのノイズを除去する(11800ms-12100ms)
#print(len(t_tracing))
#Determine sample data
sample_t= [t_tracing[4000],t_tracing[4100],t_tracing[4200],t_tracing[4300],t_tracing[4400],t_tracing[4500],t_tracing[4600],t_tracing[4700],t_tracing[4800],t_tracing[5100],t_tracing[5200],t_tracing[5300],t_tracing[5400]]
sample_Z = [Z_tracing[4000],Z_tracing[4100],Z_tracing[4200],Z_tracing[4300],Z_tracing[4400],Z_tracing[4500],Z_tracing[4600],Z_tracing[4700],Z_tracing[4800],Z_tracing[5100],Z_tracing[5200],Z_tracing[5300],Z_tracing[5400]]


f_interpld = interp1d(sample_t, sample_Z, kind='quadratic')
#tnew = np.arange(11.5,12.2,0.001)
#plt.plot(sample_t, sample_Z, 'o')
#plt.plot(tnew, f(tnew), ':')

Z_tracing_intered = Z_tracing.copy()
for t in range(4800,5100):
    Z_tracing_intered[t] = f_interpld(t/1000+7)     #ノイズの部分を補間データで調整


# 高速フーリエ変換(FFT)
F_tracing_intered = np.fft.fft(Z_tracing_intered) 

# FFTの複素数結果を絶対に変換
F_abs_intered = np.abs(F_tracing_intered)
# 振幅をもとの信号に揃える
F_abs_amp_intered = F_abs_intered / N_tracing * 2 # 交流成分はデータ数で割って2倍
F_abs_amp_intered[0] = F_abs_amp_intered[0] / 2 # 直流成分（今回は扱わないけど）は2倍不要

# 周波数軸のデータ作成
fq_tracing = np.linspace(0, Fs, N_tracing) # 周波数軸　linspace(開始,終了,分割数)


# グラフ表示
fig = plt.figure(figsize=(12, 4))
# 信号のグラフ（時間軸）
ax2 = fig.add_subplot(121)
plt.xlabel('time(sec)', fontsize=14)
plt.ylabel('amplitude', fontsize=14)
plt.plot(t_tracing, Z_tracing_intered)
fig.suptitle('Tracing', fontsize=16)


# FFTのグラフ（周波数軸）
ax2 = fig.add_subplot(122)
plt.xlabel('freqency(Hz)', fontsize=14)
plt.ylabel('amplitude', fontsize=14)
plt.plot(fq_tracing[:int(N_tracing/2)+1], F_abs_amp_intered[:int(N_tracing/2)+1]) # ナイキスト定数まで表示
ax2.set_xlim([30,250])
ax2.set_ylim([0,0.01])


#plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//filter//test1_belly//tracing_zoom.png")
# Out:
# (0, 0.01)

# %%
#次はLPF/HPFをかける
F2_breath = F.copy()
F2_tracing = F_tracing_intered.copy()


# カットオフ周波数 単位Hz
fc_hpf = 5
fc_lpf = 250

# breath process
# ハイパス処理（カットオフ周波数未満の帯域を0にする）
F2_breath[(fq_breath < fc_hpf)] = 0
F2_breath[(fq_breath > fc_lpf)] = 0

#tracing process
# ハイパス処理（カットオフ周波数未満の帯域を0にする）
F2_tracing[(fq_tracing < fc_hpf)] = 0
F2_tracing[(fq_tracing > fc_lpf)] = 0





#IFFT
Z_ifft_breath  = np.fft.ifft(F2_breath) # 逆フーリエ変換(IFFT)
Z_ifft_breath_real = Z_ifft_breath.real # 実数部
#print(Z_ifft_breath_real[:10])


plt.plot(t_breath, Z_breath, label='original') # IFFT（逆変換）
plt.plot(t_breath, Z_ifft_breath_real, c="r", linestyle='--', label='IFFT') # IFFT（逆変換）
plt.legend(loc='best')
plt.xlabel('time(sec)', fontsize=14)
plt.ylabel('signal', fontsize=14)
plt.title('Breath only', fontsize=16)


#plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//filter//test1_belly//breath_only_filtered.png")
plt.show()

Z_ifft_tracing  = np.fft.ifft(F2_tracing) # 逆フーリエ変換(IFFT)
Z_ifft_tracing_real = Z_ifft_tracing.real # 実数部
#print(Z_ifft_breath_real[:10])


plt.plot(t_tracing, Z_tracing, label='original') # IFFT（逆変換）
plt.plot(t_tracing, Z_ifft_tracing_real, c="r", linestyle='--', label='IFFT') # IFFT（逆変換）
plt.legend(loc='best')
plt.xlabel('time(sec)', fontsize=14)
plt.ylabel('signal', fontsize=14)
plt.title('Tracing', fontsize=16)


#plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//filter//test1_belly//tracing_filtered.png")
plt.show()

# %%
#コヒーレンス計算
'''
7000ms-7600ms 指先が(100,170)to (100,130)移動　こっち向きの波動があると予測している   window=7000-7511
10400ms-11500ms 指先が(80,200)to (100,80)移動　こっち向きの波動があると予測している

(130,140)-->(130,130)-->(130,120)-->(130,110)-->(130,100) 進行波動を見込みしている   window=10400-11423


'''



x_1 = 130
x_2 = 130
y_1 = 80
y_2 = 120
t1_min = 10400
t1_max = 11423
t2_min = 10400
t2_max = 11423
N_1 = t1_max-t1_min+1
N_2 = t2_max-t2_min+1


#  FFTのための設定
Fs = 1000;                 # sampling rate
Ts = 1.0/Fs;                # sampling interval 
t_1 = np.arange(t1_min/Fs,(t1_max+1)/Fs,Ts)       # time vector of breath only
t_2 = np.arange(t2_min/Fs,(t2_max+1)/Fs,Ts)       # time vector of breath only
# 周波数軸のデータ作成
fq_1 = np.linspace(0, Fs, N_1) # 周波数軸　linspace(開始,終了,分割数)
fq_2 = np.linspace(0, Fs, N_2) # 周波数軸　linspace(開始,終了,分割数)


z1 = zeros(t1_max - t1_min + 1)
z2 = zeros(t2_max - t2_min + 1)
for timing in range(t1_min,t1_max):
    z1[timing - t1_min]= f(x_1,y_1,timing)
for timing in range(t2_min,t2_max):
    z2[timing - t2_min]= f(x_2,y_2,timing)

    

Z1 = np.array(z1)# turn list into array
# 高速フーリエ変換(FFT)
F1 = np.fft.fft(Z1) 
Z2 = np.array(z2)# turn list into array
# 高速フーリエ変換(FFT)
F2 = np.fft.fft(Z2) 


# カットオフ周波数 単位Hz
fc = 360
# ハイパス処理（カットオフ周波数未満の帯域を0にする）
F1[(fq_1 < fc)] = 0

#tracing process

# ハイパス処理（カットオフ周波数未満の帯域を0にする）
F2[(fq_2 < fc)] = 0



#IFFT
Z_ifft_1  = np.fft.ifft(F1) # 逆フーリエ変換(IFFT)
Z_ifft_1_real = Z_ifft_1.real # 実数部

Z_ifft_2  = np.fft.ifft(F2) # 逆フーリエ変換(IFFT)
Z_ifft_2_real = Z_ifft_2.real # 実数部

''' 
plt.plot(t_1, Z1, label='original') # IFFT（逆変換）
plt.plot(t_1, Z_ifft_1_real, c="r", linestyle='--', label='IFFT') # IFFT（逆変換）
plt.legend(loc='best')
plt.xlabel('time(sec)', fontsize=14)
plt.ylabel('signal', fontsize=14)
plt.title('Tracing', fontsize=16)
plt.show()


plt.plot(t_2, Z2, label='original') # IFFT（逆変換）
plt.plot(t_2, Z_ifft_2_real, c="r", linestyle='--', label='IFFT') # IFFT（逆変換）
plt.legend(loc='best')
plt.xlabel('time(sec)', fontsize=14)
plt.ylabel('signal', fontsize=14)
plt.title('Tracing', fontsize=16)
plt.show()


#クロススペクトル密度
    
Pyx, freq = mlab.csd(Z_ifft_1_real, Z_ifft_2_real, NFFT=1024, Fs=1000,
                  window=mlab.window_hanning, noverlap=None)



theta1=Pyx.imag/Pyx.real
plt.plot(freq,theta1)
#plt.xlim((360, 400))
#plt.ylim((-90, 90))
'''


plt.plot(t_1, Z_ifft_1_real, t_2, Z_ifft_2_real)
plt.xlabel('Time(s)')
plt.ylabel('z1 and z2(filtered)')
plt.grid(True)
plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//filter//test1_belly//wave_signal.png")
plt.show()
 
cxy, freq = ax2.csd(Z_ifft_1_real, Z_ifft_2_real, 1000, 1. / Ts)
plt.plot(freq,cxy)
plt.xlabel('Frequency(Hz)')
plt.ylabel('CSD (db)')
plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//filter//test1_belly//wave_cross_spectrum_density.png")
plt.show()

theta1=cxy.imag/cxy.real
plt.plot(freq,theta1)
plt.xlabel('Frequency(Hz)')
plt.ylabel('Imag/Real')
plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//filter//test1_belly//wave_phase_difference.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-d0534e3524f7> in <module>()
#     106 plt.ylabel('z1 and z2(filtered)')
#     107 plt.grid(True)
# --> 108 plt.savefig("C://Users//huaju//Documents//data//fourD_sensor//20191101//Captures//animation//filter//test1_belly//wave_signal.png")
#     109 plt.show()
#     110
#
# E:\anaconda\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     708 def savefig(*args, **kwargs):
#     709     fig = gcf()
# --> 710     res = fig.savefig(*args, **kwargs)
#     711     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     712     return res
#
# E:\anaconda\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
# ...
